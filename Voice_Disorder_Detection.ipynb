# %% [markdown]
# <a href="https://colab.research.google.com/github/JAIKRISHNA2007/Voice-Disorder-Detection-App/blob/main/Voice_Disorder_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import librosa
import numpy as np

# 1. Define your 5 specific clinical disorders + Normal
pathologies = [
    'Normal',
    'Laryngitis',
    'Nodules_Polyps_Cysts',
    'Muscle_Tension_Dysphonia',
    'Spasmodic_Dysphonia',
    'Vocal_Cord_Paralysis'
]

# 2. Create the label map (AI understands numbers, not words)
# Normal=0, Laryngitis=1, Nodules=2, etc.
pathology_map = {name: i for i, name in enumerate(pathologies)}

print("App Engine successfully configured for Clinical Pathologies:")
for name, label in pathology_map.items():
    print(f"[{label}] -> {name}")
# Out:
# App Engine successfully configured for Clinical Pathologies:
# [0] -> Normal
# [1] -> Laryngitis
# [2] -> Nodules_Polyps_Cysts
# [3] -> Muscle_Tension_Dysphonia
# [4] -> Spasmodic_Dysphonia
# [5] -> Vocal_Cord_Paralysis
