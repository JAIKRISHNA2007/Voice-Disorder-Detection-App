# %% [markdown]
# <a href="https://colab.research.google.com/github/JAIKRISHNA2007/Voice-Disorder-Detection-App/blob/main/Voice_Disorder_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing the tools for audio analysis and AI
import librosa          # For "listening" to the voice and extracting MFCCs
import numpy as np      # For math and data handling
import tensorflow as tf # The main engine for building the AI model (CNN)
import os               # To organize our disorder folders

print("Step 1: Software Environment is Ready!")
# Out:
# Step 1: Software Environment is Ready!
